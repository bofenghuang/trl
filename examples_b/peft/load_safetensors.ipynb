# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "5"

# %%
from safetensors import safe_open


safetensors_path = "/home/bhuang/llm/trl/outputs/intent_classification/audio_ft/sga/sft_qwen2_5_omni_3b_lora_r64_ep10_bs64_lr2e4/adapter_model.safetensors"

tensors = {}
with safe_open(safetensors_path, framework="pt", device=0) as f:
    for k in f.keys():
        tensors[k] = f.get_tensor(k)

# %%
list(tensors.keys())
